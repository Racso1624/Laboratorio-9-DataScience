# %% [markdown]
# ## Laboratorio 9 - Visualización de Datos
# ## Data Science
#
# #### Integrantes:
# - Oscar Fernando López Barrios (20679)

# %% [markdown]
# ### Investigación de la situación

# %% [markdown]
# #### Visualización del Dataset y Limpieza de datos

# %%
# Importar librerias necesarias 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importar el csv
data = pd.read_csv("Food Share Emissions.csv")

# %%
# Visualizar la data
data
# Out:
#            Entity Code  Year  Food_emission
# 0     Afghanistan  AFG  1990      78.558522
# 1     Afghanistan  AFG  1991      79.335651
# 2     Afghanistan  AFG  1992      84.268804
# 3     Afghanistan  AFG  1993      85.247941
# 4     Afghanistan  AFG  1994      86.897834
# ...           ...  ...   ...            ...
# 5767     Zimbabwe  ZWE  2011      80.391380
# 5768     Zimbabwe  ZWE  2012      79.733619
# 5769     Zimbabwe  ZWE  2013      79.451646
# 5770     Zimbabwe  ZWE  2014      78.125762
# 5771     Zimbabwe  ZWE  2015      78.038459
#
# [5772 rows x 4 columns]

# %%
# Conocer los tipos de datos que se tienen y la info basica
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5772 entries, 0 to 5771
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Entity         5772 non-null   object
#  1   Code           5694 non-null   object
#  2   Year           5772 non-null   int64
#  3   Food_emission  5772 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 180.5+ KB

# %%
# Conocer si existen registros nulos para realizar una limpieza del dataset
data.isnull().sum()
# Out:
# Entity            0
# Code             78
# Year              0
# Food_emission     0
# dtype: int64

# %%
# Se realiza el llenado de la data null
data["Code"] = data["Code"].fillna("N/A")
data["Code"]
# Out:
# 0       AFG
# 1       AFG
# 2       AFG
# 3       AFG
# 4       AFG
#        ...
# 5767    ZWE
# 5768    ZWE
# 5769    ZWE
# 5770    ZWE
# 5771    ZWE
# Name: Code, Length: 5772, dtype: object

# %%
# Realizar la verificacion de que no existan mas nulos
data.isnull().sum()
# Out:
# Entity           0
# Code             0
# Year             0
# Food_emission    0
# dtype: int64

# %% [markdown]
# #### Visualización de Datos mediante Gráficos

# %%
# Sumatoria total de la emisión de contaminación por cada país
country_contamination_sum = data.groupby("Entity")["Food_emission"].sum().reset_index()
country_contamination_sum
# Out:
#              Entity  Food_emission
# 0       Afghanistan    2137.810728
# 1           Albania    1601.500673
# 2           Algeria     502.135669
# 3    American Samoa    2416.528107
# 4            Angola    1869.113806
# ..              ...            ...
# 217  Western Sahara    1857.456014
# 218           World    1019.234583
# 219           Yemen    1038.573544
# 220          Zambia    2611.325743
# 221        Zimbabwe    2064.378930
#
# [222 rows x 2 columns]

# %%
# Se crea la figura
plt.figure(figsize=(12, 6))

# Se utliza un grafico de barras
sns.barplot(data=country_contamination_sum, x="Entity", y="Food_emission")

# Se configuran los ejes
plt.title("Total Contaminación por País")
plt.xlabel("País")
plt.ylabel("Suma de Contaminación")
plt.xticks(rotation=90)

# Se muestra el gráfico
plt.show()
